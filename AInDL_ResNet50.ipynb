# %%
# !wget https://vignette.wikia.nocookie.net/liberapedia/images/b/bc/Elephant.jpg/revision/latest?cb=20130413020301
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20200627065220-0000
# KERNEL_ID = 770b56f5-a0d9-45e9-aac6-bfab8c0ac8d0
# --2020-06-27 06:52:23--  https://vignette.wikia.nocookie.net/liberapedia/images/b/bc/Elephant.jpg/revision/latest?cb=20130413020301
# Resolving vignette.wikia.nocookie.net (vignette.wikia.nocookie.net)... 74.120.188.194, 74.120.188.204
# Connecting to vignette.wikia.nocookie.net (vignette.wikia.nocookie.net)|74.120.188.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86706 (85K) [image/jpeg]
# Saving to: ‘latest?cb=20130413020301’
#
# 100%[======================================>] 86,706      --.-K/s   in 0.03s
#
# 2020-06-27 06:52:23 (3.10 MB/s) - ‘latest?cb=20130413020301’ saved [86706/86706]

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Tetragonula_carbonaria_%2814521993792%29.jpg/220px-Tetragonula_carbonaria_%2814521993792%29.jpg
# Out:
# --2020-06-27 06:55:09--  https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Tetragonula_carbonaria_%2814521993792%29.jpg/220px-Tetragonula_carbonaria_%2814521993792%29.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6828 (6.7K) [image/jpeg]
# Saving to: ‘220px-Tetragonula_carbonaria_(14521993792).jpg’
#
# 100%[======================================>] 6,828       --.-K/s   in 0.01s
#
# 2020-06-27 06:55:09 (503 KB/s) - ‘220px-Tetragonula_carbonaria_(14521993792).jpg’ saved [6828/6828]

# %%
# !mv latest?cb=20130413020301 elephant.jpg

# %%
# !mv 220px-Tetragonula_carbonaria_* bee.jpg

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'bee.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
preds = model.predict(x)

# %%
preds
# Out:
# array([[8.61293401e-08, 1.10458029e-06, 7.98844653e-08, 8.61948308e-08,
#         3.80903806e-08, 6.97242967e-07, 9.13367799e-08, 7.49505659e-07,
#         1.93706768e-07, 6.38499728e-07, 1.80149345e-05, 1.28270076e-05,
#         5.00547515e-07, 2.31819718e-06, 5.73260013e-06, 2.21575428e-05,
#         1.83724205e-05, 8.97938662e-07, 2.20559787e-06, 5.32736340e-06,
#         3.64503353e-06, 2.10618623e-06, 2.49322397e-07, 3.72506247e-06,
#         2.86964905e-06, 1.10816143e-06, 4.46272270e-06, 4.99276757e-06,
#         4.15351178e-06, 2.53366670e-06, 2.71097883e-06, 1.44299554e-06,
#         3.60899116e-06, 1.92198598e-07, 2.92292185e-07, 5.58465501e-07,
#         4.73496220e-06, 7.42489533e-07, 2.67236846e-05, 3.41744055e-07,
#         6.07380207e-06, 3.54847771e-06, 9.15828423e-06, 2.57883357e-06,
#         1.29986643e-06, 1.63456230e-06, 9.36815070e-07, 3.43159991e-06,
#         1.08988431e-07, 1.82525454e-07, 1.49655733e-07, 3.09103598e-07,
# ...

# %%
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# Predicted: [('n07730033', 'cardoon', 0.53187317), ('n02190166', 'fly', 0.23716733), ('n02206856', 'bee', 0.12650444)]
